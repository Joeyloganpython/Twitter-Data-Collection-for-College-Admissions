# %% [markdown]
# ## Using Twitter to Collect Data for College Admissions

# %% [markdown]
# ### Project Scope and Impact
#
# The intention of this project is to develop a mechanism to analyze Twitter data related to the freshman admissions process at Philadelphia area colleges and universities. Sentiment analysis on data culled from Twitter allows institutions the opportunity to better understand their place in an increasingly digital landscape. Twitter reactions related admissions and financial aid for an institution can provide another metric to gauge population engagement, reputation, effectiveness of communications/marketing, and many other areas of an institution.
#
# Social media is regularly monitored by the communications departments at colleges and universities to. Specifically in admissions, staff will manually check various social media feeds for any reactions - positive or negative - around the time that admissions decisions are being released. Those preliminary sentiments can provide an informal indication in how an admissions cycle might progress. Additionally, this monitoring can identify any potential issues that were not discovered during testing.
#
# A sentiment analysis of admissions Twitter data would add value to the following:
# <ul>
#     <li>Admissions and Financial Aid</li>
#     <li>Institutional Planning</li>
#     <li>Marketing and University Communications</li>

# %% [markdown]
# ### Project Development and Challenges
#
# **Preliminary Data Collection**<br>
# Utilizing Twitter’s Advanced Search functionality, an initial collection of college acceptance tweets from Drexel and West Chester University were found. Each institution notifies its admitted students of a specific hashtag (#drexelaccepted, #wcuaccepted) which was searched during December 2017, one of two major decision release seasons for the incoming 2018 class. These search parameters confirmed that data with positive sentiment should be readily available as shown in the examples below. <br>
# <a href='https://twitter.com/lanaaquino/status/941865009256296450' _target='blank'> Example of #drexelaccepted tweet</a><br>
# <a href='https://twitter.com/musicalbliss123/status/937074000488030211' _target='blank'> Example of #wcuaccepted tweet</a><br>
# <p>
# **Challenges**<br>
# <ul>
#     <li>Access to data: The Twitter API only allows access to scrape the past week of data at no expense. Decision release and notification takes place over several months. Historic access is cost prohibitive.</li>
#     <li>Identifying search terms: Finding ways to capture neutral or negative sentiment since there are not readily available hashtags or terms to search</li>

# %% [markdown]
# ### Project Data Dictionary
#
# In order to access Twitter's API, it is necessary to create an account, an application, and generate the necessary developer keys/tokens. Once configured, the API will allow access to any publicly available tweets on the site. A publicly available Tweet is any tweet that can be found via basic search on Twitter where there are no privacy restrictions on the visibility of content.
#
# **Data Dictionary**
#
# _Data Collected from Twitter_ <br>
#
# | Variable | Variable ID | Description | Data Type |
# | --- | --- | --- | --- |
# | Twitter ID | twitter_id | The unique Twitter ID - cannot be changed. | int |
# | User ID | user_id | The user ID or Twitter handle that the user creates - can be changed. | string |
# | Name | name | The name shown in the profile of the Twitter user | string |
# | User description | user_desc | The profile description created by the Twitter user | string |
# | Number of followers | number_of_followers | The number of followers the Twitter user has | int |
# | Full text | full_text | Full text of tweet | string |
# | Hashtag | hash_tag | Metadata tag added to the tweet by the Twitter user | string |
# | Retweet count | retweet_count | The number of times the tweet has been retweeted | int |
# | Create date | create_date | The date and time the tweet was created | datetime |
# | Geographic location | geo_loc | A coalesce statement that captures first, the geographic location of the Twitter user when the tweet was created, or second, the location shown in the profile of the Twitter user. This field is null if neither exist. | string |
# | Location | location | The location shown in the profile of the Twitter user | string |
# <p />
# _Function Arguments or Outputs_ <br>
#
# | Variable | Variable ID | Description | Data Type |
# | ---- | ---- | --- | --- |
# | College name | college_name | The search term put in the end user of the application, which is likely the name of a college or other related term. | string |
# | TextBlob sentiment | blob_sent | The result of the tweet's sentiment analysis using Text Blob | string |
# | NLTK sentiment | nltk_sent |The result of the tweet's sentiment analysis using the Natural Language Tool Kit | string |
# | Minor noise | minor_noise | The output of the minor_noise function that calculates the number of times a minor noise term is found in a tweet. Designed to assist in gauging the relevance of a tweet. Minor noise could include information related to the university (ex. sporting events) that is less relevant to the program objective. | int |
# | Major noise | major_noise | The output of the major_noise function that calculates the number of times a major noise term is found in a tweet. Designed to assist in gauging the relevance of a tweet. Major noise could include anything from false flags in search terms (Drexel Hill) or generated content that is in physical proximity to the institution. | int |

# %% [markdown]
# ### Program Features
#
# The program:
# <ul>
#     <li>Uses the Twitter API with a set of pre-determined search terms to capture relevant tweets and related data using Twython</li>
#     <li>Passes the full text to a function to strip the tweet of special characters and links</li>
#     <li>Passes the full text to two separate sentiment analysis to categorize the tweet</li>
#     <li>Passes the full text to two functions that calculates major and minor noise to identify the importance of the tweet relative to this project</li>
#     <li>Creates an entry of all collected and calculated data points for any new tweet in a SQLite database</li>
#     <li>Incorporates the original data plus these created fields and passes it to a function that packs it in JSON</li>
#     </ul>

# %% [markdown]
# ### Data Provided in Project Submission
#
# This project submission includes the following examples of data extracted by the program:
# <ul>
#     <li>JSON outputs of the raw Twitter data (as collected) from five separate searches (#drexelaccepted, #GoingNova, #wcuaccepted, Drexel (two searches)</li>
#     <li>JSON output from the create_json function which overwrites each time it is run (found in data directory)</li>
#     <li>The SQLite database, admissions_twitter.db, which contains the database dump from the create_table and tweet_load functions (requires SQLite or similar tool to access)</li>
#     </ul>

# %% [markdown]
# **Keys and tokens for developer account**

# %%
########### HIDDEN

# %% [markdown]
# <b>Using the package Twython</b>

# %%
from twython import Twython, TwythonError
import requests
from pprint import pprint 

twitter = Twython(CONSUMER_KEY,CONSUMER_SECRET)

# %%
#HIDDEN

# %% [markdown]
# **Initial function to collect tweets defined in parent function**

# %%
def by_college(name,number_tweets):
    results = t.search(q=name, count=number_tweets,tweet_mode='extended')
    all_tweets = results['statuses']
    return all_tweets

# %% [markdown]
# **Function to save all acquired data into a JSON file, including function parameters and execution date**

# %%
def raw_json_load(all_tweets,college_name,number_of_tweets):
    import json
    import datetime
    import re
    dateofload = datetime.datetime.now()
    dateof = str(dateofload)
    dateof = dateof.split('.')[0]
    dateof = dateof.strip(':')
    date = re.sub(':','',dateof)
    number_of_tweets = str(number_of_tweets)
    fname = "raw_"+college_name+"_"+number_of_tweets+"_"+date+".json"
    name = str(fname)
    json.dump(all_tweets, open(name, "w"))

# %% [markdown]
# <b>Utility function to strip the full text of special characters, links, etc</b>

# %%
def clean_tweet(tweet): 
    import re

    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

# %% [markdown]
# **Function to complete TextBlob Sentiment Analysis**

# %%
#Function to get sentiment using TextBlob
def get_tweet_sentiment(tweet):
    from textblob import TextBlob  
    # create TextBlob object of passed tweet text 
    analysis = TextBlob(clean_tweet(tweet)) 
    # set sentiment 
    if analysis.sentiment.polarity > 0: 
        return 'positive'
    elif analysis.sentiment.polarity == 0: 
        return 'neutral'
    else: 
        return 'negative'

# %% [markdown]
# **Function to complete Natural Language Toolkit Sentiment Analysis**

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.downloader.download('vader_lexicon')

#Function to get sentiment using NLTK

def get_tweet_sentiment_nltk(tweet):   
    import nltk
    from nltk.sentiment.vader import SentimentIntensityAnalyzer
    analysis = clean_tweet(tweet)
    sid = SentimentIntensityAnalyzer()
    for tweet in analysis:
        if (sid.polarity_scores(analysis)['compound']) >= 0.5: 
            return 'positive'
        elif (sid.polarity_scores(analysis)['compound']) <= -0.5: 
            return 'negative'
        else: 
            return 'neutral'
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Jrl362\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# **Function to calculate minor noise such as related sporting events or other school spirit activities**

# %%
def minor_noise(text): 
    m_lvl = 0
    m_noise = ('Basketball','Baseball','Soccer','Lacross','Eagles','Knights','Dragons','Play','Lead','Basket','Points','defeats','victory','game','starters','starter','offense','defense','hoops')
    for m in m_noise:
        if m.lower()in text.lower():
            m_lvl = m_lvl + 1
        else:
            m_lvl = m_lvl + 0
    return m_lvl

# %% [markdown]
# **Function to calculate major noise such as unrelated content that references the search term/institution**

# %%
def major_noise(text): 
    maj_lvl = 0
    maj_noise = ('Wendy’s','McDonald’s','Taco','Pizza','Wahoo’s','Wawa','dunkin','Drexel Hill')
    for m in maj_noise:
        if m.lower()in text.lower():
            maj_lvl = maj_lvl + 1
        else:
            maj_lvl = maj_lvl + 0
    return maj_lvl

# %% [markdown]
# **Function to create SQLite database and table if it does not exist, then update table with data.**<br>
# _Challenge_: Parsing tweets with special characters, created need for clean_tweet() function.

# %%
## function  to save data to SQLite
import sqlite3

def create_table(u,userdesc1,numfollow,f_text,hshtag,ret_cnt,create_time,c_name,twitter_id,geoloc,location,name,text_blob_sent,nltk_sent,min_noise,maj_noise):  # creates table
    ### Sql lite likes strings, had errors before conversion
    
    twitter_id = str(twitter_id)
    u=str(u)
    userdesc1 = str(userdesc1)
    f_text = str(f_text)
    hshtag = str(hshtag)
    numfollow= str(numfollow)
    ret_cnt = str(ret_cnt)
    create_time = str(create_time)
    c_name = str(c_name)
    geoloc = str(geoloc)
    location = str(location)
    name = str(name)
       
       ## cleaning
    u = u.strip()
    u = u.split('b')[1]
    u = u.strip()

    
    f_text = f_text.split('b')[1]
    f_text.split()
   
    
    ## creating the database and table if it does not exsist, then loading the data
    
    conn = sqlite3.connect('admissions_twitter1.db', timeout = 30)
    c = conn.cursor()
    c.execute('CREATE TABLE IF NOT EXISTS admissions_twitter1(twitter_id TEXT, user_id TEXT, user_desc TEXT, number_of_followers TEXT,full_text BLOB, hash_tag TEXT, retweet_count TEXT, create_date TEXT,college_name TEXT,geo_loc TEXT,location TEXT,name Text, blob_sent TEXT, nltk_sent Text, minor_noise Text, major_noise Text)')
    c.execute('INSERT INTO admissions_twitter1(twitter_id,user_id,user_desc,number_of_followers,full_text,hash_tag,retweet_count,create_date,college_name,geo_loc,location,name,blob_sent,nltk_sent,minor_noise,major_noise)VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)',(twitter_id,u,userdesc1,numfollow,f_text,hshtag,ret_cnt,create_time,c_name,geoloc,location,name,text_blob_sent,nltk_sent,min_noise,maj_noise))                    
    conn.commit()

# %% [markdown]
# <b>Function to load data into a dictionary,  in preparation to pack into a JSON file</b>

# %%
## function to create a dictonary to pack into a JSON file
import json
tweetjson = {}
def create_json(u,userdesc1,numfollow,f_text,hshtag,ret_cnt,create_time,c_name,twitter_id,geoloc,location,name,text_blob_sent,nltk_sent,min_noise,maj_noise):

 
    tweet = tweetjson.get(twitter_id,dict())
   # tweet['twitterID'] = twitter_id
    u = str(u)
    tweet['user_id'] = u
    tweet['user_desc'] = userdesc1  
    tweet['number_of_followers'] = numfollow
    tweet['full_text'] = f_text
    tweet['hash_tag'] = hshtag
    tweet['retweet_count'] = ret_cnt
    tweet['create_date'] = create_time
    tweet['college_name'] = c_name
    tweet['geo_loc'] = geoloc
    tweet['location'] = location
    tweet['name'] = name
    tweet['blob_sent'] = text_blob_sent
    tweet['nltk_sent'] = nltk_sent
    tweet['minor_noise'] = min_noise
    tweet['major_noise'] = maj_noise
    tweetjson[twitter_id] = tweet

# %%
import json
json.dump(tweetjson, open("data/tweetjson.json", "w"))

# %% [markdown]
# <b>Output of dictionary that’s being packed into JSON file</b>

# %%
tweetjson
# Out:
# {1070095700237549569: {'user_id': "b'TotalTrafficOKC'",
#   'user_desc': '',
#   'number_of_followers': 2225,
#   'full_text': "b'Accident cleared on Drexel Ave south of SW 44th St #OKCtraffic https://t.co/5PW2TfQkaY'",
#   'hash_tag': [{'text': 'OKCtraffic', 'indices': [51, 62]}],
#   'retweet_count': 0,
#   'create_date': 'Wed Feb 09 22:37:10 +0000 2011',
#   'college_name': 'Drexel',
#   'geo_loc': {'type': 'Point', 'coordinates': [35.4207, -97.569]},
#   'location': 'Oklahoma City, OK',
#   'name': 'TTN Oklahoma City',
#   'blob_sent': 'neutral',
#   'nltk_sent': 'neutral',
#   'minor_noise': 0,
#   'major_noise': 0},
#  1070090739361738752: {'user_id': "b'Drexel_XD'",
#   'user_desc': "God forgives, Drexel doesn't.",
#   'number_of_followers': 92,
# ...

# %% [markdown]
# **Parent function to collect all data, run above functions, and store all data and calculated fields**

# %%
##  function load in tweets from twitter
def tweet_load(college_name,number_of_tweets):
    # pass to web scrapper function #2
    college_name = str(college_name)
    all_tweets = by_college(college_name,number_of_tweets) # from web scraper function
    raw_json_load(all_tweets,college_name,number_of_tweets)  ## Passing to function to load raw data
    for tweet in all_tweets: #### data
        #pprint(tweet)
        inner = []
        user = tweet["user"]["screen_name"].encode('utf-8')
        userdesc = tweet["user"]["description"]
        numfollowers = tweet["user"]["followers_count"] # Number of followers, identify influencers
        twitter_id = tweet["id"]
        geoloc = tweet["geo"]
        ftext = tweet["full_text"].encode('utf-8')  # full text tweet 280 chars
        location = tweet['user']['location']
        name = tweet['user']['name']
        hashtag = tweet['entities']['hashtags'] # hashtag
        retweet_cnt = tweet['retweet_count']  
        created_at = tweet['created_at']
        
        ### get sentiment and noise
        ftext = str(ftext)
        text_blob_sent = get_tweet_sentiment(ftext) # send to  get_tweet_sentiment function that uses text blob
        nltk_sent = get_tweet_sentiment_nltk(ftext) # send to get_tweet_sentiment_nltk fuction that uses nltk
        min_noise = minor_noise(ftext)#  send to minor noise function
        maj_noise = major_noise(ftext) # send to major noise function
        
        #add data to table, will create database and table if not exsit 
        create_table(user,userdesc,numfollowers,ftext,hashtag,retweet_cnt,created_at,college_name,twitter_id,geoloc,location,name,text_blob_sent,nltk_sent,min_noise,maj_noise) 
        create_json(user,userdesc,numfollowers,ftext,hashtag,retweet_cnt,created_at,college_name,twitter_id,geoloc,location,name,text_blob_sent,nltk_sent,min_noise,maj_noise)

# %% [markdown]
# <b>This runs the program</b>

# %%
##Runs program using pre-determined search term
#additional search terms to build into a list and iterate through: 
#wcuaccepted #wcu #goingnova, #drexel, #futuredragons, #newdragons, Drexel, Villanova, West Chester

tweet_load("Drexel",100)

# %% [markdown]
# ### Next Steps
#
# In looking at continued improvement and refinement of this project, we propose the following:
# <ul>
#     <li>Running the program during critical decision timeframes - December and March at a minimum - to collect relevant data</li>
#     <li>Investigate the Twitter Streaming API following presentation Q&A - see below</li>
#     <li>Create lists to hold major function parameters such as Twitter search terms and major/minor noise terms to be loaded into respective functions. Ensures the integrity of the core code while creating more robust function parameters</li>
#     <li>Using search term list to iterate through terms instead of running manually each time</li>
#     <li>Identify application of noise parameters, sentiment analysis, etc after a critical mass of data is collected</li>

# %% [markdown]
# ### Twitter Streaming API
#
# Following in-class discussion about Twitter's streaming API and its benefits to allowing us to collect relevant data in real time. What we need to look more closely at is the organization of the data elements to collect and store them as we did with the rest API above. Their nested dictionary structure has some similarities to the soccer tournament data. Most notably, the full_text value of the tweet is not contained in all results. These updates are the first priority to improve data collection going into the next segment of the course. Proper configuration will include a restarter script and some kind of schedule to dump the data for sentiment analysis and storage. Below is the commented out code and a sample result to demonstrate the availability of data.

# %% [markdown]
# ### Twython Streaming Class to print live Twitter data

# %% [raw]
# from twython import TwythonStreamer
# from pprint import pprint
#
# i=0
# retrytime = 1
#
# class MyStreamer(TwythonStreamer):
#     def on_success(self, data):
#         if 'text' in data:
#         pprint(data)
#             print(data['user_desc'])
#     def on_error(self, status_code, data):
#         pprint(status_code)
#         i += 1
#         retrytime = 2 ** i
#
#         # Want to stop trying to get data because of the error?
#         # Uncomment the next line!
#         # self.disconnect()
#
# stream = MyStreamer(CONSUMER_KEY, CONSUMER_SECRET,
#                     ACCESS_TOKEN, ACCESS_TOKEN_SECRET, retry_in=retrytime)
# stream.statuses.filter(track='Trump')

# %%
from twython import TwythonStreamer
from pprint import pprint

i=0
retrytime = 1

class MyStreamer(TwythonStreamer):
    def on_success(self, data):
        if 'text' in data:
            pprint(data)
          #  print(data['user_desc'])
    def on_error(self, status_code, data):
        pprint(status_code)
        i += 1
        retrytime = 2 ** i

        # Want to stop trying to get data because of the error?
        # Uncomment the next line!
        # self.disconnect() 

stream = MyStreamer(CONSUMER_KEY, CONSUMER_SECRET,
                    ACCESS_TOKEN, ACCESS_TOKEN_SECRET, retry_in=retrytime)
stream.statuses.filter(track='Trump')

# %% [markdown]
# ### Sample output from Twitter streaming API searching for 'Drexel'

# %% [raw]
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Dec 10 01:29:25 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'cci.drexel.edu/bigdata/bigdat…',
#                         'expanded_url': 'http://cci.drexel.edu/bigdata/bigdata2018/index.html',
#                         'indices': [62, 85],
#                         'url': 'https://t.co/HflqJoIdYz'}],
#               'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1071939911119302657,
#  'id_str': '1071939911119302657',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'ja',
#  'place': None,
#  'possibly_sensitive': False,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://about.twitter.com/products/tweetdeck" '
#            'rel="nofollow">TweetDeck</a>',
#  'text': 'そういえば，KubeConと全く同じ日程で，シアトルではIEEEのBigDataカンファレンスが開かれている様子 &gt; '
#          'https://t.co/HflqJoIdYz',
#  'timestamp_ms': '1544405365148',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Mon Jun 11 05:58:31 +0000 2007',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': "I'm not familiar with programming but I can develop "
#                          'D language and Fluentd a little.',
#           'favourites_count': 316,
#           'follow_request_sent': None,
#           'followers_count': 7195,
#           'following': None,
#           'friends_count': 3516,
#           'geo_enabled': False,
#           'id': 6731442,
#           'id_str': '6731442',
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 667,
#           'location': 'You',
#           'name': 'SKSの申し子',
#           'notifications': None,
#           'profile_background_color': '000000',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/6731442/1348044094',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1062588363624996864/DynBn_18_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1062588363624996864/DynBn_18_normal.jpg',
#           'profile_link_color': '1B95E0',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '000000',
#           'profile_text_color': '000000',
#           'profile_use_background_image': False,
#           'protected': False,
#           'screen_name': 'repeatedly',
#           'statuses_count': 393679,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'http://repeatedly.github.io/',
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Dec 10 01:32:40 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 199287107,
#                                  'id_str': '199287107',
#                                  'indices': [0, 9],
#                                  'name': 'Rhody MBB',
#                                  'screen_name': 'RhodyMBB'},
#                                 {'id': 3023940424,
#                                  'id_str': '3023940424',
#                                  'indices': [22, 36],
#                                  'name': '• Isaiah Wilson •',
#                                  'screen_name': 'born_poised23'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1071940729868566529,
#  'id_str': '1071940729868566529',
#  'in_reply_to_screen_name': 'RhodyMBB',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': 199287107,
#  'in_reply_to_user_id_str': '199287107',
#  'is_quote_status': True,
#  'lang': 'en',
#  'place': None,
#  'quote_count': 0,
#  'quoted_status': {'contributors': None,
#                    'coordinates': None,
#                    'created_at': 'Sun Dec 09 21:57:23 +0000 2018',
#                    'display_text_range': [0, 140],
#                    'entities': {'hashtags': [],
#                                 'symbols': [],
#                                 'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                           'expanded_url': 'https://twitter.com/i/web/status/1071886551758573569',
#                                           'indices': [117, 140],
#                                           'url': 'https://t.co/fV0P6oigE3'}],
#                                 'user_mentions': [{'id': 3232289248,
#                                                    'id_str': '3232289248',
#                                                    'indices': [79, 95],
#                                                    'name': 'First Love Hoops',
#                                                    'screen_name': 'Firstlove_hoops'}]},
#                    'extended_tweet': {'display_text_range': [0, 250],
#                                       'entities': {'hashtags': [],
#                                                    'media': [{'display_url': 'pic.twitter.com/JH9d4oU5O2',
#                                                               'expanded_url': 'https://twitter.com/BigShotsNation/status/1071886551758573569/photo/1',
#                                                               'id': 1071886543759978496,
#                                                               'id_str': '1071886543759978496',
#                                                               'indices': [251,
#                                                                           274],
#                                                               'media_url': 'http://pbs.twimg.com/media/DuAbIehVsAASBPY.jpg',
#                                                               'media_url_https': 'https://pbs.twimg.com/media/DuAbIehVsAASBPY.jpg',
#                                                               'sizes': {'large': {'h': 1536,
#                                                                                   'resize': 'fit',
#                                                                                   'w': 2048},
#                                                                         'medium': {'h': 900,
#                                                                                    'resize': 'fit',
#                                                                                    'w': 1200},
#                                                                         'small': {'h': 510,
#                                                                                   'resize': 'fit',
#                                                                                   'w': 680},
#                                                                         'thumb': {'h': 150,
#                                                                                   'resize': 'crop',
#                                                                                   'w': 150}},
#                                                               'type': 'photo',
#                                                               'url': 'https://t.co/JH9d4oU5O2'}],
#                                                    'symbols': [],
#                                                    'urls': [],
#                                                    'user_mentions': [{'id': 3232289248,
#                                                                       'id_str': '3232289248',
#                                                                       'indices': [79,
#                                                                                   95],
#                                                                       'name': 'First '
#                                                                               'Love '
#                                                                               'Hoops',
#                                                                       'screen_name': 'Firstlove_hoops'},
#                                                                      {'id': 361911482,
#                                                                       'id_str': '361911482',
#                                                                       'indices': [129,
#                                                                                   142],
#                                                                       'name': 'MonumentalSportsNet',
#                                                                       'screen_name': 'MonSportsNet'}]},
#                                       'extended_entities': {'media': [{'display_url': 'pic.twitter.com/JH9d4oU5O2',
#                                                                        'expanded_url': 'https://twitter.com/BigShotsNation/status/1071886551758573569/photo/1',
#                                                                        'id': 1071886543759978496,
#                                                                        'id_str': '1071886543759978496',
#                                                                        'indices': [251,
#                                                                                    274],
#                                                                        'media_url': 'http://pbs.twimg.com/media/DuAbIehVsAASBPY.jpg',
#                                                                        'media_url_https': 'https://pbs.twimg.com/media/DuAbIehVsAASBPY.jpg',
#                                                                        'sizes': {'large': {'h': 1536,
#                                                                                            'resize': 'fit',
#                                                                                            'w': 2048},
#                                                                                  'medium': {'h': 900,
#                                                                                             'resize': 'fit',
#                                                                                             'w': 1200},
#                                                                                  'small': {'h': 510,
#                                                                                            'resize': 'fit',
#                                                                                            'w': 680},
#                                                                                  'thumb': {'h': 150,
#                                                                                            'resize': 'crop',
#                                                                                            'w': 150}},
#                                                                        'type': 'photo',
#                                                                        'url': 'https://t.co/JH9d4oU5O2'}]},
#                                       'full_text': 'When you stuff the stat '
#                                                    'sheet 15 pts 8 rebs 6 ast '
#                                                    '6 stls like Isaiah Wilson '
#                                                    'of @Firstlove_hoops you '
#                                                    'get a post-game interview '
#                                                    'on @MonSportsNet. \n'
#                                                    'Wilson holds offers from '
#                                                    'Rhode Island, Winthrop, '
#                                                    'Drexel, Kent State. And '
#                                                    'more to come that saw him '
#                                                    'today! '
#                                                    'https://t.co/JH9d4oU5O2'},
#                    'favorite_count': 26,
#                    'favorited': False,
#                    'filter_level': 'low',
#                    'geo': None,
#                    'id': 1071886551758573569,
#                    'id_str': '1071886551758573569',
#                    'in_reply_to_screen_name': None,
#                    'in_reply_to_status_id': None,
#                    'in_reply_to_status_id_str': None,
#                    'in_reply_to_user_id': None,
#                    'in_reply_to_user_id_str': None,
#                    'is_quote_status': False,
#                    'lang': 'en',
#                    'place': None,
#                    'possibly_sensitive': False,
#                    'quote_count': 2,
#                    'reply_count': 0,
#                    'retweet_count': 10,
#                    'retweeted': False,
#                    'source': '<a href="http://twitter.com/download/iphone" '
#                              'rel="nofollow">Twitter for iPhone</a>',
#                    'text': 'When you stuff the stat sheet 15 pts 8 rebs 6 ast '
#                            '6 stls like Isaiah Wilson of @Firstlove_hoops you '
#                            'get a post-game… https://t.co/fV0P6oigE3',
#                    'truncated': True,
#                    'user': {'contributors_enabled': False,
#                             'created_at': 'Wed May 06 18:06:17 +0000 2009',
#                             'default_profile': False,
#                             'default_profile_image': False,
#                             'description': 'Tournament Circuit - Camps - Color '
#                                            'Commentator | '
#                                            'http://bigshots.net/2018-schedule/ '
#                                            '| http://bigshots.net/rankings/ | '
#                                            'Kevin Schneider kevin@bigshots.net',
#                             'favourites_count': 13045,
#                             'follow_request_sent': None,
#                             'followers_count': 30978,
#                             'following': None,
#                             'friends_count': 20747,
#                             'geo_enabled': True,
#                             'id': 38238029,
#                             'id_str': '38238029',
#                             'is_translator': False,
#                             'lang': 'en',
#                             'listed_count': 138,
#                             'location': None,
#                             'name': 'BIG SHOTS',
#                             'notifications': None,
#                             'profile_background_color': '000000',
#                             'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                             'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                             'profile_background_tile': False,
#                             'profile_banner_url': 'https://pbs.twimg.com/profile_banners/38238029/1481566031',
#                             'profile_image_url': 'http://pbs.twimg.com/profile_images/644206380950384641/rEaEbV0w_normal.jpg',
#                             'profile_image_url_https': 'https://pbs.twimg.com/profile_images/644206380950384641/rEaEbV0w_normal.jpg',
#                             'profile_link_color': 'F57428',
#                             'profile_sidebar_border_color': '000000',
#                             'profile_sidebar_fill_color': 'DDFFCC',
#                             'profile_text_color': '333333',
#                             'profile_use_background_image': True,
#                             'protected': False,
#                             'screen_name': 'BigShotsNation',
#                             'statuses_count': 88182,
#                             'time_zone': None,
#                             'translator_type': 'none',
#                             'url': 'http://www.bigshots.net',
#                             'utc_offset': None,
#                             'verified': False}},
#  'quoted_status_id': 1071886551758573569,
#  'quoted_status_id_str': '1071886551758573569',
#  'quoted_status_permalink': {'display': 'twitter.com/bigshotsnation…',
#                              'expanded': 'https://twitter.com/bigshotsnation/status/1071886551758573569',
#                              'url': 'https://t.co/IsQrKI0mtL'},
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/#!/download/ipad" '
#            'rel="nofollow">Twitter for iPad</a>',
#  'text': '@RhodyMBB ‘20 recruit @born_poised23 earns tourney MVP honors this '
#          'weekend.',
#  'timestamp_ms': '1544405560353',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Thu Mar 14 02:46:09 +0000 2013',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': None,
#           'favourites_count': 18366,
#           'follow_request_sent': None,
#           'followers_count': 124,
#           'following': None,
#           'friends_count': 255,
#           'geo_enabled': True,
#           'id': 1266016921,
#           'id_str': '1266016921',
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': None,
#           'name': 'Dave Cotter',
#           'notifications': None,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1027975838422261767/BnmIp7cE_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1027975838422261767/BnmIp7cE_normal.jpg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'cotter_dave',
#           'statuses_count': 5022,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Dec 10 01:41:15 +0000 2018',
#  'entities': {'hashtags': [{'indices': [56, 70], 'text': 'impressionism'},
#                            {'indices': [71, 87], 'text': 'giovanniboldini'}],
#               'media': [{'display_url': 'pic.twitter.com/82qbjrLlca',
#                          'expanded_url': 'https://twitter.com/artistboldini/status/1068389282417643521/photo/1',
#                          'id': 1068389280387661824,
#                          'id_str': '1068389280387661824',
#                          'indices': [88, 111],
#                          'media_url': 'http://pbs.twimg.com/media/DtOuY9NXgAAgJR5.jpg',
#                          'media_url_https': 'https://pbs.twimg.com/media/DtOuY9NXgAAgJR5.jpg',
#                          'sizes': {'large': {'h': 1253,
#                                              'resize': 'fit',
#                                              'w': 714},
#                                    'medium': {'h': 1200,
#                                               'resize': 'fit',
#                                               'w': 684},
#                                    'small': {'h': 680,
#                                              'resize': 'fit',
#                                              'w': 387},
#                                    'thumb': {'h': 150,
#                                              'resize': 'crop',
#                                              'w': 150}},
#                          'source_status_id': 1068389282417643521,
#                          'source_status_id_str': '1068389282417643521',
#                          'source_user_id': 819803766375399424,
#                          'source_user_id_str': '819803766375399424',
#                          'type': 'photo',
#                          'url': 'https://t.co/82qbjrLlca'}],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 819803766375399424,
#                                  'id_str': '819803766375399424',
#                                  'indices': [3, 17],
#                                  'name': 'Giovanni Boldini',
#                                  'screen_name': 'artistboldini'}]},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/82qbjrLlca',
#                                   'expanded_url': 'https://twitter.com/artistboldini/status/1068389282417643521/photo/1',
#                                   'id': 1068389280387661824,
#                                   'id_str': '1068389280387661824',
#                                   'indices': [88, 111],
#                                   'media_url': 'http://pbs.twimg.com/media/DtOuY9NXgAAgJR5.jpg',
#                                   'media_url_https': 'https://pbs.twimg.com/media/DtOuY9NXgAAgJR5.jpg',
#                                   'sizes': {'large': {'h': 1253,
#                                                       'resize': 'fit',
#                                                       'w': 714},
#                                             'medium': {'h': 1200,
#                                                        'resize': 'fit',
#                                                        'w': 684},
#                                             'small': {'h': 680,
#                                                       'resize': 'fit',
#                                                       'w': 387},
#                                             'thumb': {'h': 150,
#                                                       'resize': 'crop',
#                                                       'w': 150}},
#                                   'source_status_id': 1068389282417643521,
#                                   'source_status_id_str': '1068389282417643521',
#                                   'source_user_id': 819803766375399424,
#                                   'source_user_id_str': '819803766375399424',
#                                   'type': 'photo',
#                                   'url': 'https://t.co/82qbjrLlca'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1071942888710389760,
#  'id_str': '1071942888710389760',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Fri Nov 30 06:20:29 +0000 2018',
#                       'display_text_range': [0, 68],
#                       'entities': {'hashtags': [{'indices': [37, 51],
#                                                  'text': 'impressionism'},
#                                                 {'indices': [52, 68],
#                                                  'text': 'giovanniboldini'}],
#                                    'media': [{'display_url': 'pic.twitter.com/82qbjrLlca',
#                                               'expanded_url': 'https://twitter.com/artistboldini/status/1068389282417643521/photo/1',
#                                               'id': 1068389280387661824,
#                                               'id_str': '1068389280387661824',
#                                               'indices': [69, 92],
#                                               'media_url': 'http://pbs.twimg.com/media/DtOuY9NXgAAgJR5.jpg',
#                                               'media_url_https': 'https://pbs.twimg.com/media/DtOuY9NXgAAgJR5.jpg',
#                                               'sizes': {'large': {'h': 1253,
#                                                                   'resize': 'fit',
#                                                                   'w': 714},
#                                                         'medium': {'h': 1200,
#                                                                    'resize': 'fit',
#                                                                    'w': 684},
#                                                         'small': {'h': 680,
#                                                                   'resize': 'fit',
#                                                                   'w': 387},
#                                                         'thumb': {'h': 150,
#                                                                   'resize': 'crop',
#                                                                   'w': 150}},
#                                               'type': 'photo',
#                                               'url': 'https://t.co/82qbjrLlca'}],
#                                    'symbols': [],
#                                    'urls': [],
#                                    'user_mentions': []},
#                       'extended_entities': {'media': [{'display_url': 'pic.twitter.com/82qbjrLlca',
#                                                        'expanded_url': 'https://twitter.com/artistboldini/status/1068389282417643521/photo/1',
#                                                        'id': 1068389280387661824,
#                                                        'id_str': '1068389280387661824',
#                                                        'indices': [69, 92],
#                                                        'media_url': 'http://pbs.twimg.com/media/DtOuY9NXgAAgJR5.jpg',
#                                                        'media_url_https': 'https://pbs.twimg.com/media/DtOuY9NXgAAgJR5.jpg',
#                                                        'sizes': {'large': {'h': 1253,
#                                                                            'resize': 'fit',
#                                                                            'w': 714},
#                                                                  'medium': {'h': 1200,
#                                                                             'resize': 'fit',
#                                                                             'w': 684},
#                                                                  'small': {'h': 680,
#                                                                            'resize': 'fit',
#                                                                            'w': 387},
#                                                                  'thumb': {'h': 150,
#                                                                            'resize': 'crop',
#                                                                            'w': 150}},
#                                                        'type': 'photo',
#                                                        'url': 'https://t.co/82qbjrLlca'}]},
#                       'favorite_count': 58,
#                       'favorited': False,
#                       'filter_level': 'low',
#                       'geo': None,
#                       'id': 1068389282417643521,
#                       'id_str': '1068389282417643521',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'is_quote_status': False,
#                       'lang': 'en',
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'quote_count': 0,
#                       'reply_count': 0,
#                       'retweet_count': 24,
#                       'retweeted': False,
#                       'source': '<a href="https://www.offtheeasel.com/" '
#                                 'rel="nofollow">Off The Easel Bots</a>',
#                       'text': 'Portrait of Elizabeth Wharton Drexel '
#                               '#impressionism #giovanniboldini '
#                               'https://t.co/82qbjrLlca',
#                       'truncated': False,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Fri Jan 13 07:10:23 +0000 2017',
#                                'default_profile': True,
#                                'default_profile_image': False,
#                                'description': 'Fan account of Giovanni '
#                                               'Boldini, an Italian genre and '
#                                               'portrait painter who lived and '
#                                               'worked in Paris for most of his '
#                                               'career. Account managed by '
#                                               '@andreitr',
#                                'favourites_count': 27,
#                                'follow_request_sent': None,
#                                'followers_count': 2086,
#                                'following': None,
#                                'friends_count': 112,
#                                'geo_enabled': False,
#                                'id': 819803766375399424,
#                                'id_str': '819803766375399424',
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 69,
#                                'location': '(World) Florence, Italy',
#                                'name': 'Giovanni Boldini',
#                                'notifications': None,
#                                'profile_background_color': 'F5F8FA',
#                                'profile_background_image_url': '',
#                                'profile_background_image_url_https': '',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/819803766375399424/1509054296',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/923665662223958016/xzvbkQec_normal.jpg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/923665662223958016/xzvbkQec_normal.jpg',
#                                'profile_link_color': '1DA1F2',
#                                'profile_sidebar_border_color': 'C0DEED',
#                                'profile_sidebar_fill_color': 'DDEEF6',
#                                'profile_text_color': '333333',
#                                'profile_use_background_image': True,
#                                'protected': False,
#                                'screen_name': 'artistboldini',
#                                'statuses_count': 7113,
#                                'time_zone': None,
#                                'translator_type': 'none',
#                                'url': 'https://en.wikipedia.org/wiki/Giovanni_Boldini',
#                                'utc_offset': None,
#                                'verified': False}},
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'text': 'RT @artistboldini: Portrait of Elizabeth Wharton Drexel '
#          '#impressionism #giovanniboldini https://t.co/82qbjrLlca',
#  'timestamp_ms': '1544406075061',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun Jul 19 02:10:35 +0000 2015',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I draw. I paint. I take photos. \n'
#                          'TURN THE GLOBE UPSIDE DOWN and who is on top❓\n'
#                          'ig, facebook: @griffitzart \n'
#                          'email: griffitz@rogers.com \n'
#                          '🇨🇦🇯🇲🇬🇧',
#           'favourites_count': 41512,
#           'follow_request_sent': None,
#           'followers_count': 531,
#           'following': None,
#           'friends_count': 511,
#           'geo_enabled': False,
#           'id': 3382582510,
#           'id_str': '3382582510',
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 45,
#           'location': None,
#           'name': 'GriiffitzArt',
#           'notifications': None,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3382582510/1471412138',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/677639412772130817/GozKMM-X_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/677639412772130817/GozKMM-X_normal.jpg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'griffitzart',
#           'statuses_count': 17462,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Dec 10 01:45:35 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 38238029,
#                                  'id_str': '38238029',
#                                  'indices': [3, 18],
#                                  'name': 'BIG SHOTS',
#                                  'screen_name': 'BigShotsNation'},
#                                 {'id': 3232289248,
#                                  'id_str': '3232289248',
#                                  'indices': [99, 115],
#                                  'name': 'First Love Hoops',
#                                  'screen_name': 'Firstlove_hoops'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1071943980571594752,
#  'id_str': '1071943980571594752',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Sun Dec 09 21:57:23 +0000 2018',
#                       'display_text_range': [0, 140],
#                       'entities': {'hashtags': [],
#                                    'symbols': [],
#                                    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                              'expanded_url': 'https://twitter.com/i/web/status/1071886551758573569',
#                                              'indices': [117, 140],
#                                              'url': 'https://t.co/fV0P6oigE3'}],
#                                    'user_mentions': [{'id': 3232289248,
#                                                       'id_str': '3232289248',
#                                                       'indices': [79, 95],
#                                                       'name': 'First Love '
#                                                               'Hoops',
#                                                       'screen_name': 'Firstlove_hoops'}]},
#                       'extended_tweet': {'display_text_range': [0, 250],
#                                          'entities': {'hashtags': [],
#                                                       'media': [{'display_url': 'pic.twitter.com/JH9d4oU5O2',
#                                                                  'expanded_url': 'https://twitter.com/BigShotsNation/status/1071886551758573569/photo/1',
#                                                                  'id': 1071886543759978496,
#                                                                  'id_str': '1071886543759978496',
#                                                                  'indices': [251,
#                                                                              274],
#                                                                  'media_url': 'http://pbs.twimg.com/media/DuAbIehVsAASBPY.jpg',
#                                                                  'media_url_https': 'https://pbs.twimg.com/media/DuAbIehVsAASBPY.jpg',
#                                                                  'sizes': {'large': {'h': 1536,
#                                                                                      'resize': 'fit',
#                                                                                      'w': 2048},
#                                                                            'medium': {'h': 900,
#                                                                                       'resize': 'fit',
#                                                                                       'w': 1200},
#                                                                            'small': {'h': 510,
#                                                                                      'resize': 'fit',
#                                                                                      'w': 680},
#                                                                            'thumb': {'h': 150,
#                                                                                      'resize': 'crop',
#                                                                                      'w': 150}},
#                                                                  'type': 'photo',
#                                                                  'url': 'https://t.co/JH9d4oU5O2'}],
#                                                       'symbols': [],
#                                                       'urls': [],
#                                                       'user_mentions': [{'id': 3232289248,
#                                                                          'id_str': '3232289248',
#                                                                          'indices': [79,
#                                                                                      95],
#                                                                          'name': 'First '
#                                                                                  'Love '
#                                                                                  'Hoops',
#                                                                          'screen_name': 'Firstlove_hoops'},
#                                                                         {'id': 361911482,
#                                                                          'id_str': '361911482',
#                                                                          'indices': [129,
#                                                                                      142],
#                                                                          'name': 'MonumentalSportsNet',
#                                                                          'screen_name': 'MonSportsNet'}]},
#                                          'extended_entities': {'media': [{'display_url': 'pic.twitter.com/JH9d4oU5O2',
#                                                                           'expanded_url': 'https://twitter.com/BigShotsNation/status/1071886551758573569/photo/1',
#                                                                           'id': 1071886543759978496,
#                                                                           'id_str': '1071886543759978496',
#                                                                           'indices': [251,
#                                                                                       274],
#                                                                           'media_url': 'http://pbs.twimg.com/media/DuAbIehVsAASBPY.jpg',
#                                                                           'media_url_https': 'https://pbs.twimg.com/media/DuAbIehVsAASBPY.jpg',
#                                                                           'sizes': {'large': {'h': 1536,
#                                                                                               'resize': 'fit',
#                                                                                               'w': 2048},
#                                                                                     'medium': {'h': 900,
#                                                                                                'resize': 'fit',
#                                                                                                'w': 1200},
#                                                                                     'small': {'h': 510,
#                                                                                               'resize': 'fit',
#                                                                                               'w': 680},
#                                                                                     'thumb': {'h': 150,
#                                                                                               'resize': 'crop',
#                                                                                               'w': 150}},
#                                                                           'type': 'photo',
#                                                                           'url': 'https://t.co/JH9d4oU5O2'}]},
#                                          'full_text': 'When you stuff the stat '
#                                                       'sheet 15 pts 8 rebs 6 '
#                                                       'ast 6 stls like Isaiah '
#                                                       'Wilson of '
#                                                       '@Firstlove_hoops you '
#                                                       'get a post-game '
#                                                       'interview on '
#                                                       '@MonSportsNet. \n'
#                                                       'Wilson holds offers '
#                                                       'from Rhode Island, '
#                                                       'Winthrop, Drexel, Kent '
#                                                       'State. And more to come '
#                                                       'that saw him today! '
#                                                       'https://t.co/JH9d4oU5O2'},
#                       'favorite_count': 26,
#                       'favorited': False,
#                       'filter_level': 'low',
#                       'geo': None,
#                       'id': 1071886551758573569,
#                       'id_str': '1071886551758573569',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'is_quote_status': False,
#                       'lang': 'en',
#                       'place': None,
#                       'possibly_sensitive': False,
#                       'quote_count': 3,
#                       'reply_count': 0,
#                       'retweet_count': 11,
#                       'retweeted': False,
#                       'source': '<a href="http://twitter.com/download/iphone" '
#                                 'rel="nofollow">Twitter for iPhone</a>',
#                       'text': 'When you stuff the stat sheet 15 pts 8 rebs 6 '
#                               'ast 6 stls like Isaiah Wilson of '
#                               '@Firstlove_hoops you get a post-game… '
#                               'https://t.co/fV0P6oigE3',
#                       'truncated': True,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Wed May 06 18:06:17 +0000 2009',
#                                'default_profile': False,
#                                'default_profile_image': False,
#                                'description': 'Tournament Circuit - Camps - '
#                                               'Color Commentator | '
#                                               'http://bigshots.net/2018-schedule/ '
#                                               '| http://bigshots.net/rankings/ '
#                                               '| Kevin Schneider '
#                                               'kevin@bigshots.net',
#                                'favourites_count': 13045,
#                                'follow_request_sent': None,
#                                'followers_count': 30978,
#                                'following': None,
#                                'friends_count': 20747,
#                                'geo_enabled': True,
#                                'id': 38238029,
#                                'id_str': '38238029',
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 138,
#                                'location': None,
#                                'name': 'BIG SHOTS',
#                                'notifications': None,
#                                'profile_background_color': '000000',
#                                'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/38238029/1481566031',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/644206380950384641/rEaEbV0w_normal.jpg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/644206380950384641/rEaEbV0w_normal.jpg',
#                                'profile_link_color': 'F57428',
#                                'profile_sidebar_border_color': '000000',
#                                'profile_sidebar_fill_color': 'DDFFCC',
#                                'profile_text_color': '333333',
#                                'profile_use_background_image': True,
#                                'protected': False,
#                                'screen_name': 'BigShotsNation',
#                                'statuses_count': 88182,
#                                'time_zone': None,
#                                'translator_type': 'none',
#                                'url': 'http://www.bigshots.net',
#                                'utc_offset': None,
#                                'verified': False}},
#  'source': '<a href="http://twitter.com/download/android" '
#            'rel="nofollow">Twitter for Android</a>',
#  'text': 'RT @BigShotsNation: When you stuff the stat sheet 15 pts 8 rebs 6 '
#          'ast 6 stls like Isaiah Wilson of @Firstlove_hoops you get a '
#          'post-game int…',
#  'timestamp_ms': '1544406335381',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun Jan 30 23:59:10 +0000 2011',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Philippians 2:1-11\n'
#                          '#MomentoMori⌛ #FlyEaglesFly🏆  #AdrenalineJunky😈\n'
#                          'when you © me throw ya✌🏿 🚶🚶@7inagain\n'
#                          '#Excelsior🚀',
#           'favourites_count': 10677,
#           'follow_request_sent': None,
#           'followers_count': 1269,
#           'following': None,
#           'friends_count': 1088,
#           'geo_enabled': True,
#           'id': 245138033,
#           'id_str': '245138033',
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 19,
#           'location': 'Homewood U Smucc',
#           'name': '👽',
#           'notifications': None,
#           'profile_background_color': '131516',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#           'profile_background_tile': True,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/245138033/1381301442',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1068175188574027776/3FX3SJjC_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1068175188574027776/3FX3SJjC_normal.jpg',
#           'profile_link_color': '1B95E0',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': 'EFEFEF',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'PredTheGREAT',
#           'statuses_count': 78316,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'http://knotzland.com',
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': {'coordinates': [121.2044465, 13.845232], 'type': 'Point'},
#  'created_at': 'Mon Dec 10 01:45:39 +0000 2018',
#  'entities': {'hashtags': [{'indices': [60, 68], 'text': 'drexels'},
#                            {'indices': [69, 79], 'text': 'drexelsph'}],
#               'symbols': [],
#               'urls': [{'display_url': 'instagram.com/p/BrMFiWkAdyT/…',
#                         'expanded_url': 'https://www.instagram.com/p/BrMFiWkAdyT/?utm_source=ig_twitter_share&igshid=15rzeul1e17wy',
#                         'indices': [91, 114],
#                         'url': 'https://t.co/UJ8N93dRcl'}],
#               'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': {'coordinates': [13.845232, 121.2044465], 'type': 'Point'},
#  'id': 1071943995910221824,
#  'id_str': '1071943995910221824',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': {'attributes': {},
#            'bounding_box': {'coordinates': [[[121.158926, 13.76334],
#                                              [121.158926, 13.873811],
#                                              [121.32612, 13.873811],
#                                              [121.32612, 13.76334]]],
#                             'type': 'Polygon'},
#            'country': 'Republic of the Philippines',
#            'country_code': 'PH',
#            'full_name': 'Rosario, Calabarzon',
#            'id': '0155a9a75374d970',
#            'name': 'Rosario',
#            'place_type': 'city',
#            'url': 'https://api.twitter.com/1.1/geo/id/0155a9a75374d970.json'},
#  'possibly_sensitive': False,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#  'text': 'Weekend crew! ❤️ Congratulations to Ate Mais and Kuya Drex! #drexels '
#          "#drexelsph @ Drexel's https://t.co/UJ8N93dRcl",
#  'timestamp_ms': '1544406339038',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Mon Jun 07 10:24:41 +0000 2010',
#           'default_profile': False,
#           'default_profile_image': False,
#           'description': 'Silently judging you in my mind.',
#           'favourites_count': 7600,
#           'follow_request_sent': None,
#           'followers_count': 300,
#           'following': None,
#           'friends_count': 533,
#           'geo_enabled': True,
#           'id': 152971563,
#           'id_str': '152971563',
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 4,
#           'location': 'Philippines',
#           'name': 'Cassey Reyes',
#           'notifications': None,
#           'profile_background_color': 'E8CCAE',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/152971563/1529225982',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1064451825259110406/XUEL20Nn_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1064451825259110406/XUEL20Nn_normal.jpg',
#           'profile_link_color': 'E63350',
#           'profile_sidebar_border_color': '000000',
#           'profile_sidebar_fill_color': '830F88',
#           'profile_text_color': 'AF62B5',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'kaseyreyes',
#           'statuses_count': 18911,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': 'http://Instagram.com/cassfreyes',
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Mon Dec 10 01:47:58 +0000 2018',
#  'display_text_range': [0, 140],
#  'entities': {'hashtags': [{'indices': [32, 39], 'text': 'opiate'}],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                         'expanded_url': 'https://twitter.com/i/web/status/1071944579061071872',
#                         'indices': [117, 140],
#                         'url': 'https://t.co/CQDKdMsKIN'}],
#               'user_mentions': []},
#  'extended_tweet': {'display_text_range': [0, 263],
#                     'entities': {'hashtags': [{'indices': [32, 39],
#                                                'text': 'opiate'},
#                                               {'indices': [190, 201],
#                                                'text': 'PHLOpioids'},
#                                               {'indices': [244, 263],
#                                                'text': 'RecoveryIsPossible'}],
#                                  'media': [{'display_url': 'pic.twitter.com/AxJoGh1otV',
#                                             'expanded_url': 'https://twitter.com/freedom91313/status/1071944579061071872/photo/1',
#                                             'id': 1071944571905396736,
#                                             'id_str': '1071944571905396736',
#                                             'indices': [264, 287],
#                                             'media_url': 'http://pbs.twimg.com/media/DuBP6KNUUAAUCad.jpg',
#                                             'media_url_https': 'https://pbs.twimg.com/media/DuBP6KNUUAAUCad.jpg',
#                                             'sizes': {'large': {'h': 1489,
#                                                                 'resize': 'fit',
#                                                                 'w': 1242},
#                                                       'medium': {'h': 1200,
#                                                                  'resize': 'fit',
#                                                                  'w': 1001},
#                                                       'small': {'h': 680,
#                                                                 'resize': 'fit',
#                                                                 'w': 567},
#                                                       'thumb': {'h': 150,
#                                                                 'resize': 'crop',
#                                                                 'w': 150}},
#                                             'type': 'photo',
#                                             'url': 'https://t.co/AxJoGh1otV'}],
#                                  'symbols': [],
#                                  'urls': [],
#                                  'user_mentions': []},
#                     'extended_entities': {'media': [{'display_url': 'pic.twitter.com/AxJoGh1otV',
#                                                      'expanded_url': 'https://twitter.com/freedom91313/status/1071944579061071872/photo/1',
#                                                      'id': 1071944571905396736,
#                                                      'id_str': '1071944571905396736',
#                                                      'indices': [264, 287],
#                                                      'media_url': 'http://pbs.twimg.com/media/DuBP6KNUUAAUCad.jpg',
#                                                      'media_url_https': 'https://pbs.twimg.com/media/DuBP6KNUUAAUCad.jpg',
#                                                      'sizes': {'large': {'h': 1489,
#                                                                          'resize': 'fit',
#                                                                          'w': 1242},
#                                                                'medium': {'h': 1200,
#                                                                           'resize': 'fit',
#                                                                           'w': 1001},
#                                                                'small': {'h': 680,
#                                                                          'resize': 'fit',
#                                                                          'w': 567},
#                                                                'thumb': {'h': 150,
#                                                                          'resize': 'crop',
#                                                                          'w': 150}},
#                                                      'type': 'photo',
#                                                      'url': 'https://t.co/AxJoGh1otV'}]},
#                     'full_text': 'I am in long term recovery from #opiate My '
#                                  'homegroup is located near Drexel University. '
#                                  'The information is listed on the flyer. We '
#                                  'welcome you even if your using an MAT.  🚫No '
#                                  'Judgement Zone #PHLOpioids Come and study '
#                                  'the Twelve Steps with us!! '
#                                  '#RecoveryIsPossible https://t.co/AxJoGh1otV'},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1071944579061071872,
#  'id_str': '1071944579061071872',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'text': 'I am in long term recovery from #opiate My homegroup is located near '
#          'Drexel University. The information is listed o… '
#          'https://t.co/CQDKdMsKIN',
#  'timestamp_ms': '1544406478072',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sat Jan 23 05:37:25 +0000 2010',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': '#USAFVeteran, paralegal studies major @bucks_edu '
#                          'Intern at Bucks County Public Defender’s Office, My '
#                          'passion is serving the community @missioncontinue',
#           'favourites_count': 4971,
#           'follow_request_sent': None,
#           'followers_count': 1198,
#           'following': None,
#           'friends_count': 1633,
#           'geo_enabled': True,
#           'id': 107630010,
#           'id_str': '107630010',
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 31,
#           'location': 'Pennsylvania, USA',
#           'name': 'Michael DiMaio',
#           'notifications': None,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/107630010/1542081985',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/1047330849824366592/M6C9cw8o_normal.jpg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1047330849824366592/M6C9cw8o_normal.jpg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'freedom91313',
#           'statuses_count': 14746,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
